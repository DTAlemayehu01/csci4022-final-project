# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import make_blobs
from matplotlib.patches import Ellipse
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture

# %%
citizens, _ = make_blobs(n_samples=300, centers=5, n_features=2, cluster_std=0.8, random_state=42)
citizens.shape
# Out:
# (300, 2)

# %%
plt.scatter(citizens[:, 0], citizens[:, 1], alpha=0.6, s=20)
plt.title('Random Citizen Political Spread', fontsize=12)
plt.xlabel('X'); 
plt.ylabel('Y')
plt.grid(True, alpha=0.3)

# %% [markdown]
# # Kmeans

# %%
kmeans = KMeans(n_clusters=2, random_state=42, n_init=10).fit(data)
kmeans.cluster_centers_

kmeans.inertia_

plt.plot(*zip(*data[0:3]), color='red', marker='o', linestyle='', label="M_1")
plt.plot(*zip(*data[3:6]), color='blue', marker='o', linestyle='', label="M_2")
plt.plot(*zip(*kmeans.cluster_centers_), color='green', marker='*', markersize=12, linestyle='', label="Centroids")
plt.xlabel("x_1")
plt.ylabel("x_2")
plt.legend()

wcss_list = []
for k in range(1,5):
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10).fit(data)
    wcss_list.append(kmeans.inertia_)
plt.plot(range(1,5), wcss_list, marker='o')
plt.xlabel("k")
plt.ylabel("WCSS")

# %%
kmeans = KMeans(n_clusters=2, random_state=42, n_init=10).fit(citizens)
display(kmeans.cluster_centers_)
display(kmeans.inertia_)

plt.scatter(citizens[:, 0], citizens[:, 1], alpha=0.6, s=20, c=kmeans.predict(citizens))
plt.plot(*zip(*kmeans.cluster_centers_), color='red', marker='*', markersize=12, linestyle='', label="Centroids")
plt.title('2 Candidate Fit', fontsize=12)
plt.xlabel('X'); 
plt.ylabel('Y')
plt.grid(True, alpha=0.3)
# Out:
# array([[-6.72493927, -6.95157001],
#        [-1.22487027,  5.61687694]])
# 8303.27063462746

# %%
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10).fit(citizens)
display(kmeans.cluster_centers_)
display(kmeans.inertia_)

plt.scatter(citizens[:, 0], citizens[:, 1], alpha=0.6, s=20, c=kmeans.predict(citizens))
plt.plot(*zip(*kmeans.cluster_centers_), color='red', marker='*', markersize=12, linestyle='', label="Centroids")
plt.title('3 Candidate Fit', fontsize=12)
plt.xlabel('X'); 
plt.ylabel('Y')
plt.grid(True, alpha=0.3)
# Out:
# array([[ 3.28199754,  3.10477075],
#        [-5.73173808,  8.12898313],
#        [-6.72493927, -6.95157001]])
# 1913.8622457051652

# %%
kmeans = KMeans(n_clusters=4, random_state=42, n_init=10).fit(citizens)
display(kmeans.cluster_centers_)
display(kmeans.inertia_)

plt.scatter(citizens[:, 0], citizens[:, 1], alpha=0.6, s=20, c=kmeans.predict(citizens))
plt.plot(*zip(*kmeans.cluster_centers_), color='red', marker='*', markersize=12, linestyle='', label="Centroids")
plt.title('4 Candidate Fit', fontsize=12)
plt.xlabel('X'); 
plt.ylabel('Y')
plt.grid(True, alpha=0.3)
# Out:
# array([[ 3.28199754,  3.10477075],
#        [-8.84492491,  7.30505644],
#        [-6.72493927, -6.95157001],
#        [-2.61855125,  8.95290982]])
# 669.3677562266859

# %%
kmeans = KMeans(n_clusters=5, random_state=42, n_init=10).fit(citizens)
display(kmeans.cluster_centers_)
display(kmeans.inertia_)
display(kmeans.predict(citizens))

plt.scatter(citizens[:, 0], citizens[:, 1], alpha=0.6, s=20, c=kmeans.predict(citizens))
plt.plot(*zip(*kmeans.cluster_centers_), color='red', marker='*', markersize=12, linestyle='', label="Centroids")
plt.title('5 Candidate Fit', fontsize=12)
plt.xlabel('X'); 
plt.ylabel('Y')
plt.grid(True, alpha=0.3)
# Out:
# array([[ 4.52768424,  2.13392438],
#        [-8.84492491,  7.30505644],
#        [-6.72493927, -6.95157001],
#        [-2.61855125,  8.95290982],
#        [ 1.99408418,  4.10852717]])
# 359.8719539303222
# array([3, 4, 3, 0, 3, 1, 4, 2, 1, 4, 0, 3, 0, 3, 4, 3, 0, 0, 4, 3, 3, 0,
#        3, 4, 4, 3, 2, 4, 0, 2, 1, 4, 4, 1, 2, 0, 0, 4, 1, 0, 3, 0, 2, 1,
#        4, 1, 3, 2, 4, 2, 1, 4, 2, 1, 3, 1, 0, 3, 1, 2, 3, 1, 4, 4, 2, 0,
#        2, 2, 2, 2, 0, 2, 1, 4, 1, 3, 1, 1, 4, 3, 2, 3, 3, 4, 3, 2, 1, 0,
#        0, 4, 4, 4, 3, 4, 3, 3, 4, 1, 0, 4, 1, 1, 0, 2, 3, 3, 3, 0, 3, 0,
#        1, 4, 0, 0, 3, 3, 3, 2, 1, 1, 1, 2, 1, 1, 3, 2, 4, 4, 1, 3, 0, 1,
#        0, 3, 3, 3, 3, 0, 2, 4, 3, 1, 3, 0, 4, 3, 4, 2, 0, 2, 0, 2, 2, 0,
#        3, 4, 2, 1, 3, 0, 1, 1, 4, 0, 3, 1, 4, 4, 0, 4, 2, 3, 0, 0, 3, 0,
#        1, 0, 2, 2, 1, 1, 0, 2, 2, 4, 3, 1, 2, 0, 4, 2, 3, 2, 2, 1, 1, 2,
#        4, 0, 1, 2, 0, 0, 1, 3, 3, 2, 2, 3, 2, 1, 4, 2, 3, 0, 1, 1, 2, 4,
# ...

# %%
kmeans = KMeans(n_clusters=6, random_state=42, n_init=10).fit(citizens)
display(kmeans.cluster_centers_)
display(kmeans.inertia_)
display(kmeans.predict(citizens))

plt.scatter(citizens[:, 0], citizens[:, 1], alpha=0.6, s=20, c=kmeans.predict(citizens))
plt.plot(*zip(*kmeans.cluster_centers_), color='red', marker='*', markersize=12, linestyle='', label="Centroids")
plt.title('6 Candidate Fit', fontsize=12)
plt.xlabel('X'); 
plt.ylabel('Y')
plt.grid(True, alpha=0.3)
# Out:
# array([[-2.61855125,  8.95290982],
#        [-6.72493927, -6.95157001],
#        [ 2.00561319,  4.07992744],
#        [-9.46389999,  7.29858625],
#        [ 4.55838189,  2.12961407],
#        [-7.84918238,  7.315465  ]])
# 322.77281694651765
# array([0, 2, 0, 4, 0, 3, 2, 1, 5, 2, 4, 0, 4, 0, 2, 0, 4, 4, 2, 0, 0, 4,
#        0, 2, 2, 0, 1, 2, 4, 1, 5, 2, 2, 5, 1, 4, 4, 2, 3, 4, 0, 4, 1, 5,
#        2, 3, 0, 1, 2, 1, 3, 2, 1, 5, 0, 3, 4, 0, 3, 1, 0, 3, 2, 2, 1, 4,
#        1, 1, 1, 1, 4, 1, 3, 2, 3, 0, 3, 3, 2, 0, 1, 0, 0, 2, 0, 1, 3, 4,
#        4, 2, 2, 2, 0, 2, 0, 0, 2, 5, 4, 2, 3, 3, 4, 1, 0, 0, 0, 4, 0, 4,
#        5, 2, 4, 4, 0, 0, 0, 1, 3, 3, 3, 1, 5, 5, 0, 1, 2, 2, 3, 0, 4, 3,
#        4, 0, 0, 0, 0, 4, 1, 2, 0, 3, 0, 4, 2, 0, 2, 1, 4, 1, 4, 1, 1, 4,
#        0, 2, 1, 5, 0, 4, 3, 5, 2, 4, 0, 5, 2, 2, 4, 2, 1, 0, 4, 4, 0, 4,
#        3, 4, 1, 1, 3, 5, 4, 1, 1, 2, 0, 3, 1, 4, 2, 1, 0, 1, 1, 5, 3, 1,
#        2, 4, 5, 1, 4, 4, 3, 0, 0, 1, 1, 0, 1, 5, 2, 1, 0, 4, 5, 5, 1, 2,
# ...

# %% [markdown]
# # GMM

# %%
def draw_ellipse(position, covariance, ax, **kwargs):
    U, s, Vt = np.linalg.svd(covariance)
    angle = np.degrees(np.arctan2(U[1, 0], U[0, 0]))
    width, height = 2*np.sqrt(s)
    for nsig in range(1, 3):
        ax.add_patch(Ellipse(position, nsig * width, nsig * height, angle=angle, alpha=0.3, **kwargs))

# %%
n = 2
gmm = GaussianMixture(n_components=n, covariance_type='full', random_state=42)
display(gmm.fit(citizens))
display(gmm.means_)
display(gmm.weights_)
display(gmm.predict_proba(citizens)[0:5])

fig, ax = plt.subplots()
ax.scatter(citizens[:, 0], citizens[:, 1], c=gmm.fit_predict(citizens), s=30, cmap='viridis')
colors = plt.cm.viridis(np.linspace(0, 1, 2*n))
for k in range(n):
    draw_ellipse(gmm.means_[k], gmm.covariances_[k], ax, fc=colors[k])
# Out:
# GaussianMixture(n_components=2, random_state=42)
# array([[ 1.3131084 ,  5.0549911 ],
#        [-7.78548217,  0.17354577]])
# array([0.60015868, 0.39984132])
# array([[1.00000000e+00, 1.05207869e-19],
#        [1.00000000e+00, 1.59109585e-26],
#        [1.00000000e+00, 3.21034708e-13],
#        [1.00000000e+00, 7.50878145e-47],
#        [9.99999999e-01, 7.89961066e-10]])

# %%
n = 3
gmm = GaussianMixture(n_components=n, covariance_type='full', random_state=42)
display(gmm.fit(citizens))
display(gmm.means_)
display(gmm.weights_)
display(gmm.predict_proba(citizens)[0:5])

fig, ax = plt.subplots()
ax.scatter(citizens[:, 0], citizens[:, 1], c=gmm.fit_predict(citizens), s=30, cmap='viridis')
colors = plt.cm.viridis(np.linspace(0, 1, 2*n))
for k in range(n):
    draw_ellipse(gmm.means_[k], gmm.covariances_[k], ax, fc=colors[k])
# Out:
# GaussianMixture(n_components=3, random_state=42)
# array([[ 3.28045565,  3.10610492],
#        [-5.732796  ,  8.12909781],
#        [-6.72493927, -6.95157001]])
# array([0.40011538, 0.39988462, 0.2       ])
# array([[6.56928448e-005, 9.99934307e-001, 1.93795328e-146],
#        [9.99999971e-001, 2.93211688e-008, 7.97197887e-097],
#        [5.45464231e-003, 9.94545358e-001, 1.07417008e-113],
#        [1.00000000e+000, 3.52099296e-024, 1.00779954e-094],
#        [3.74376647e-006, 9.99996256e-001, 1.02740456e-137]])

# %%
n = 6
gmm = GaussianMixture(n_components=n, covariance_type='full', random_state=42)
display(gmm.fit(citizens))
display(gmm.means_)
display(gmm.weights_)
display(gmm.predict_proba(citizens)[0:5])

fig, ax = plt.subplots()
ax.scatter(citizens[:, 0], citizens[:, 1], c=gmm.fit_predict(citizens), s=30, cmap='viridis')
colors = plt.cm.viridis(np.linspace(0, 1, 2*n))
for k in range(n):
    draw_ellipse(gmm.means_[k], gmm.covariances_[k], ax, fc=colors[k])
# Out:
# GaussianMixture(n_components=6, random_state=42)
# array([[ 4.54394681,  2.1375009 ],
#        [-8.8449245 ,  7.30505682],
#        [-6.72493927, -6.95157001],
#        [-2.61855234,  8.95290925],
#        [ 1.4742342 ,  3.82174441],
#        [ 2.38903022,  4.28043747]])
# array([0.20145084, 0.19999998, 0.2       , 0.20000002, 0.08408741,
#        0.11446175])
# array([[1.69554530e-027, 5.07890978e-016, 4.22728996e-146,
#         1.00000000e+000, 4.19661882e-019, 2.12694693e-020],
#        [1.03256665e-007, 1.17285359e-023, 2.54832599e-096,
#         6.57173655e-010, 9.84067716e-001, 1.59321802e-002],
#        [6.21771866e-028, 2.73947760e-010, 2.94866586e-114,
#         1.00000000e+000, 9.07877776e-013, 1.93662279e-029],
#        [9.99972869e-001, 9.81945717e-051, 6.99744872e-095,
#         3.66984120e-037, 2.60763389e-005, 1.05454285e-006],
#        [1.91499146e-042, 1.41948197e-008, 7.66693695e-138,
#         9.99999986e-001, 8.61537477e-026, 1.28698149e-049]])

# %%
n = 10
gmm = GaussianMixture(n_components=n, covariance_type='full', random_state=42)
display(gmm.fit(citizens))
display(gmm.means_)
display(gmm.weights_)
display(gmm.predict_proba(citizens)[0:5])

fig, ax = plt.subplots()
ax.scatter(citizens[:, 0], citizens[:, 1], c=gmm.fit_predict(citizens), s=30, cmap='viridis')
colors = plt.cm.viridis(np.linspace(0, 1, 2*n))
for k in range(n):
    draw_ellipse(gmm.means_[k], gmm.covariances_[k], ax, fc=colors[k])
